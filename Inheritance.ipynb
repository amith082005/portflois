# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Base class
class Vehicle:
    def __init__(self, brand, wheels):
        self.brand = brand
        self.wheels = wheels

    def display_info(self):
        print("Brand:", self.brand)
        print("Number of wheels:", self.wheels)

# Derived class
class Car(Vehicle):
    def __init__(self, brand, wheels, fuel_type):
        super().__init__(brand, wheels)  # Call parent constructor
        self.fuel_type = fuel_type

    def display_car_info(self):
        self.display_info()  # Call method from parent
        print("Fuel type:", self.fuel_type)

# Create object
my_car = Car("Toyota", 4, "Petrol")

# Display details
my_car.display_car_info()
# Out:
# Brand: Toyota
# Number of wheels: 4
# Fuel type: Petrol
