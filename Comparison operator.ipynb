# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Comparison%20operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Comparison Operator Example Program

# Declare variables
a = 10
b = 5

# Perform comparisons
print("a =", a)
print("b =", b)

print("a > b:", a > b)        # Greater than
print("a < b:", a < b)        # Less than
print("a == b:", a == b)      # Equal to
print("a != b:", a != b)      # Not equal to
print("a >= b:", a >= b)      # Greater than or equal to
print("a <= b:", a <= b)      # Less than or equal to
# Out:
# a = 10
# b = 5
# a > b: True
# a < b: False
# a == b: False
# a != b: True
# a >= b: True
# a <= b: False
