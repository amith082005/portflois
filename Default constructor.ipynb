# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Default%20constructor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vehicle:
    # Default constructor (no parameters)
    def __init__(self):
        self.type = "Car"
        self.brand = "Toyota"
        self.wheels = 4

    def display_info(self):
        print("Vehicle Type:", self.type)
        print("Brand:", self.brand)
        print("Number of wheels:", self.wheels)

# Create object (calls default constructor)
v1 = Vehicle()

# Display vehicle information
v1.display_info()
# Out:
# Vehicle Type: Car
# Brand: Toyota
# Number of wheels: 4
