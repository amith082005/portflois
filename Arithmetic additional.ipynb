# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Arithmetic%20additional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Arithmetic Addition Example

# Declare integers
num1 = 8
num2 = 12

# Add the numbers
sum_result = num1 + num2

# Display the result
print("The sum of", num1, "and", num2, "is:", sum_result)
# Out:
# The sum of 8 and 12 is: 20
