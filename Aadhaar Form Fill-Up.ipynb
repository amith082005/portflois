# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Aadhaar%20Form%20Fill-Up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aadhaar Form Fill-up Example Program

def aadhaar_form():
    print("=== Aadhaar Enrollment Form ===")

    # Get user inputs
    name = input("Enter your full name: ")
    age = input("Enter your age: ")
    gender = input("Enter your gender (Male/Female/Other): ")
    address = input("Enter your full address: ")
    phone = input("Enter your mobile number: ")

    # Print confirmation
    print("\n--- Aadhaar Form Details ---")
    print("Name:     ", name)
    print("Age:      ", age)
    print("Gender:   ", gender)
    print("Address:  ", address)
    print("Phone No: ", phone)

# Run the form
aadhaar_form()
# Out:
# === Aadhaar Enrollment Form ===
