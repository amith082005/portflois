# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Constructor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Person:
    # Constructor: __init__ is called automatically when object is created
    def __init__(self, name, age):
        self.name = name  # Instance variable
        self.age = age

    # Method to display person info
    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)

# Create Person object (constructor is called here)
p1 = Person("Amith", 22)

# Call display method
p1.display()
# Out:
# Name: Amith
# Age: 22
