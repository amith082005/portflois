# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Float Example Program

# Declare float numbers
x = 10.5
y = 3.2

# Perform operations
sum_result = x + y
diff_result = x - y
product_result = x * y
quotient_result = x / y

# Display results
print("x =", x)
print("y =", y)
print("Sum =", sum_result)
print("Difference =", diff_result)
print("Product =", product_result)
print("Quotient =", quotient_result)
# Out:
# x = 10.5
# y = 3.2
# Sum = 13.7
# Difference = 7.3
# Product = 33.6
# Quotient = 3.28125
