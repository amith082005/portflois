# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Boolean Example Program

# Declare boolean variables
is_raining = True
have_umbrella = False

# Conditional logic using boolean values
if is_raining and not have_umbrella:
    print("You will get wet!")
elif is_raining and have_umbrella:
    print("You will stay dry.")
else:
    print("Enjoy the sunshine!")
# Out:
# You will get wet!
