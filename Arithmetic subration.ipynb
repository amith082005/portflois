# %% [markdown]
# <a href="https://colab.research.google.com/github/amith082005/portflois/blob/main/Arithmetic%20subration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Arithmetic Subtraction Example

# Declare numbers
num1 = 20
num2 = 7

# Subtract the numbers
difference = num1 - num2

# Display the result
print("The difference between", num1, "and", num2, "is:", difference)
# Out:
# The difference between 20 and 7 is: 13
